# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1AO5B7/VITBML-EDA1/blob/master/Copy_of_Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TOPIC: AWS Honeypot Attack Data
#
# Explore Data:
#     we explore the data from the online sources https//www.kaggle.com/casimian2000/aws-honeypot-attack-data

# %% [markdown]
# # Description

# %% [markdown]
# **It describes about the Honeypot Attack on the Amazon Web Services**
#
# Data has 451,581 data points collected from 9:53pm on 3 March 2013 to 5:55am on 8 September 2013.

# %% [markdown]
# The variables in the data are::
#
#
# * datetime -it describes about the time and date when the threat occured to honeypot_marx-geo.
#
# *   host -it describes about the host of the threat
#
# *   src -it describes about the source of threat
#
# *   proto
#
# *  type
# *   spt
#
# *   dpt
# *   srcstr
#
#
#
# * cc
#
#
#
#
# *   country- it says from which country does the threat occured
#
# *  locale -it describes the city from yhe country described the previuos column or variable
#
#
# *   localeabbr -it describes the abbreviated form of the locality in the country given in the previous column
#
#
# *   postalcode - it shows the postal code of the location
#
#
# *   latitude - it gives the latitudinal co-ordinates of the location
#
#
# *   longitude - it gives the longitudinal co-ordinates of the location
# *   unnamed:15

# %% [markdown]
# # Questions

# %% [markdown]
#
#
#
#
#
# 1. what is the most effected datetime for honeypot max-geo?
# 1.in which place the maximum host is given?
#
# 1.   which is avg effected type of honeypot max-geo?
#
# 1.   in which place the maximum spt is given?
# 5.   which is the most effected country by aws honeypot?
#
# 6.   what is avg dpt noted?
#
# 7.    What is the maximum latitude range?
# 8.   which cc noted more no of times about th honeypot?
# 1.     what is the max longitude range?
# 10.  what is avg postalcode noted?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#reading the dNew Sectionata
a=pd.read_csv('AWS_Honeypot_marx-geo.csv')
print(a)
# Out:
#             datetime               host  ...  longitude Unnamed: 15
# 0       3/3/13 21:53     groucho-oregon  ...   115.9333         NaN
# 1       3/3/13 21:57     groucho-oregon  ...     9.0000         NaN
# 2       3/3/13 21:58     groucho-oregon  ...   121.5250         NaN
# 3       3/3/13 21:58    groucho-us-east  ...  -122.9117         NaN
# 4       3/3/13 21:58  groucho-singapore  ...     2.3500         NaN
# ...              ...                ...  ...        ...         ...
# 451576   9/8/13 5:54     groucho-oregon  ...   139.7514         NaN
# 451577   9/8/13 5:50         groucho-eu  ...   117.2808         NaN
# 451578   9/8/13 5:55     groucho-oregon  ...  -118.2642         NaN
# 451579   9/8/13 5:55      groucho-tokyo  ...   121.5250         NaN
# 451580   9/8/13 5:55      groucho-tokyo  ...   121.5250         NaN
#
# [451581 rows x 16 columns]

# %% [markdown]
# # Preliminary Analysis

# %%
 # dimensions of the data
a.shape
# Out:
# (451581, 16)

# %%
#columns of the data
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9744 entries, 0 to 9743
# Data columns (total 16 columns):
# datetime       9744 non-null object
# host           9744 non-null object
# src            9744 non-null int64
# proto          9744 non-null object
# type           727 non-null float64
# spt            9017 non-null float64
# dpt            9017 non-null float64
# srcstr         9744 non-null object
# cc             9636 non-null object
# country        9636 non-null object
# locale         7301 non-null object
# localeabbr     6975 non-null object
# postalcode     1907 non-null object
# latitude       9656 non-null float64
# longitude      9656 non-null float64
# Unnamed: 15    0 non-null float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# dimensions
a.ndim
# Out:
# 2

# %% [markdown]
# # **Central Tendency of the variables**

# %%
a.describe()
# Out:
#                 src          type  ...      longitude  Unnamed: 15
# count  4.515810e+05  44811.000000  ...  448153.000000    83.000000
# mean   2.154902e+09      7.514896  ...      48.751751   -77.027536
# std    1.081011e+09      1.799866  ...      91.774739     0.011942
# min    1.677725e+07      0.000000  ...    -175.000000   -77.059600
# 25%    1.169129e+09      8.000000  ...      -4.000000   -77.036400
# 50%    2.031191e+09      8.000000  ...     106.000000   -77.036400
# 75%    3.164988e+09      8.000000  ...     118.777800   -77.014600
# max    3.758094e+09     13.000000  ...     178.416700   -77.014600
#
# [8 rows x 7 columns]

# %% [markdown]
# # Checking whether the data contains the nan valiues

# %%
a.isna()
# Out:
#       datetime   host    src  ...  latitude  longitude  Unnamed: 15
# 0        False  False  False  ...     False      False         True
# 1        False  False  False  ...     False      False         True
# 2        False  False  False  ...     False      False         True
# 3        False  False  False  ...     False      False         True
# 4        False  False  False  ...     False      False         True
# ...        ...    ...    ...  ...       ...        ...          ...
# 9739     False  False  False  ...     False      False         True
# 9740     False  False  False  ...     False      False         True
# 9741     False  False  False  ...     False      False         True
# 9742     False  False  False  ...     False      False         True
# 9743     False  False  False  ...      True       True         True
#
# [9744 rows x 16 columns]

# %% [markdown]
# # Cleaning the dataset

# %%
a.fillna(0)
# Out:
#           datetime               host  ...  longitude Unnamed: 15
# 0     3/3/13 21:53     groucho-oregon  ...   115.9333         0.0
# 1     3/3/13 21:57     groucho-oregon  ...     9.0000         0.0
# 2     3/3/13 21:58     groucho-oregon  ...   121.5250         0.0
# 3     3/3/13 21:58    groucho-us-east  ...  -122.9117         0.0
# 4     3/3/13 21:58  groucho-singapore  ...     2.3500         0.0
# ...            ...                ...  ...        ...         ...
# 9739  3/9/13 13:36     groucho-oregon  ...   118.7778         0.0
# 9740  3/9/13 13:37  groucho-singapore  ...   116.3883         0.0
# 9741  3/9/13 13:38         groucho-sa  ...   -83.3491         0.0
# 9742  3/9/13 13:37     groucho-norcal  ...   123.4328         0.0
# 9743  3/9/13 13:40      groucho-tokyo  ...     0.0000         0.0
#
# [9744 rows x 16 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451581 entries, 0 to 451580
# Data columns (total 16 columns):
# datetime       451581 non-null object
# host           451581 non-null object
# src            451581 non-null int64
# proto          451581 non-null object
# type           44811 non-null float64
# spt            406770 non-null float64
# dpt            406770 non-null float64
# srcstr         451581 non-null object
# cc             447985 non-null object
# country        447947 non-null object
# locale         342112 non-null object
# localeabbr     331705 non-null object
# postalcode     86478 non-null object
# latitude       448112 non-null float64
# longitude      448153 non-null float64
# Unnamed: 15    83 non-null float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 55.1+ MB

# %% [markdown]
# # Finding Variability of variables in dataset

# %%
a.var()     # variance of the data
# Out:
# src            1.084620e+18
# type           6.693502e+00
# spt            4.289075e+08
# dpt            1.108630e+08
# latitude       2.202264e+02
# longitude      8.118102e+03
# Unnamed: 15             NaN
# dtype: float64

# %% [markdown]
# # Data type and sub-category

# %%
a.dtypes
# Out:
# datetime        object
# host            object
# src              int64
# proto           object
# type           float64
# spt            float64
# dpt            float64
# srcstr          object
# cc              object
# country         object
# locale          object
# localeabbr      object
# postalcode      object
# latitude       float64
# longitude      float64
# Unnamed: 15    float64
# dtype: object

# %% [markdown]
# # To describe whether the data is positively skewed or negatively skewed

# %% [markdown]
# **Plotting histogram for latitude**

# %%
plt.hist(a['latitude'])
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([ 108.,   98.,   86.,   90.,  161.,  822., 3462., 3511.,  907.,
#          411.]),
#  array([-39.8    , -29.07012, -18.34024,  -7.61036,   3.11952,  13.8494 ,
#          24.57928,  35.30916,  46.03904,  56.76892,  67.4988 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# *From the above histogram plot we can say that variable-latitude is negatively skewed

# %% [markdown]
# **Plotting histogram for longitude**

# %%
plt.hist(a['longitude'])
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([1166., 1056.,  190.,   72., 1100.,  399.,  278., 3215., 2152.,
#           28.]),
#  array([-123.12   ,  -92.96633,  -62.81266,  -32.65899,   -2.50532,
#           27.64835,   57.80202,   87.95569,  118.10936,  148.26303,
#          178.4167 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Finding the outliers

# %%
sb.boxplot(a['latitude'])

# %% [markdown]
# * from the above box plot we can say that 20,000 is an outlier  in the latitude column

# %% [markdown]
# # Describing the correlation between variables

# %% [markdown]
# **Describing correlation between src and latitude**

# %%
plt.scatter(a['src'],a['latitude'],c='green')
plt.xlabel=('src')
plt.ylabel=('latitude')
plt.show()

# %% [markdown]
# * Above scatter plot shows that src and latitude are not correlated

# %% [markdown]
# ** * Describing correlation between src and longitude**
#
# ---

# %%
plt.scatter(a['src'],a['longitude'],c='red')

# %% [markdown]
# From the above scatter plot we can say that src and longitudes are not correlated

# %% [markdown]
# # Analysis of data with graphs

# %% [markdown]
# # Line Plot between (latitude and dpt) and (latitude and longitude)

# %%
p=a['latitude']
q=a['longitudeNew Section']
r=a['dpt']
plt.plot(p,r,color='r',label='lineone',marker='o',markerfacecolor='r')
plt.plot(q,r,color='b',label='linetwo',marker='o',markerfacecolor='b')
plt.legend()
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.title('line plot')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
p=a['src']
q=a['spt']
plt.plot(p,color='b',label='lineone',marker='o',markerfacecolor='b')
plt.plot(q,color='yellow',label='linetwo',marker='o',markerfacecolor='yellow')
plt.legend()
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.title('line plot')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
p=a['dbold textpt']
q=a['src']
plt.plot(p,color='red',label='lineone',marker='o',markerfacecolor='red')
plt.plot(q,color='yellow',label='linetwo',marker='o',markerfacecolor='yellow')
plt.legend()
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.title('line plot')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Answers

# %% [markdown]
# **Question 1**
# * Finding the most effected datetime is done by clculating the mode of that variable/column

# %%
# Time in which most honeypot_marx-geo occur
a['datetime'].mode()
# Out:
# 0    3/7/13 15:10
# 1    3/8/13 17:02
# dtype: object

# %% [markdown]
# **Question 2**

# %% [markdown]
# *Finding the host which hosted most of the times with the help ofmode() function

# %%
#Maximum hosting is given in...
a['host'].mode()
# Out:
# 0    groucho-oregon
# dtype: object

# %% [markdown]
# **Question 3**
#
#
# *Finding the mean type with the help of mean()
# function

# %%
#Mean effected type
a['type'].mean()
# Out:
# 6.5928473177441544

# %% [markdown]
# **Qestion 4**
#
#
# *Finding the maximum spt using max() function

# %%
a['spt'].max
# Out:
# <bound method Series.max of 0        6000.0
# 1        5270.0
# 2        2489.0
# 3       43235.0
# 4       56577.0
#          ...
# 9739     6000.0
# 9740     6000.0
# 9741        NaN
# 9742    27947.0
# 9743     8888.0
# Name: spt, Length: 9744, dtype: float64>

# %% [markdown]
# **Question 5**
#
#
# *Finding the most effected country using mode()

# %%
#most effected country
a['country'].mode()
# Out:
# 0    China
# dtype: object

# %% [markdown]
# **Question 6**
#
#
# *Finding the average dpt noted using mean() function

# %%
#avg dpt noted
a['dpt'].mean()
# Out:
# 5181.376400133082

# %% [markdown]
# **Question 7**
#
#
# *Finding the maximum latitudinal range using max() function

# %%
# max latitude range
a['latitude'].max()
# Out:
# 67.4988

# %% [markdown]
# **Question 8**
#
#
# *Finding the most occured cc using yhe mode() function

# %%
a['cc'].mode()
# Out:
# 0    CN
# dtype: object

# %% [markdown]
# **Question 9**
#
#
# *Finding the maximum longitudinal range using the mode() function

# %%
#max lonitude range
a['longitude'].mode()
# Out:
# 0    116.3883
# dtype: float64

# %% [markdown]
# **Question 10**
#
#
# *Finding the postal code of the most occured locations

# %%
# postalcode noted
a['postalcode'].mode()
# Out:
# 0    91789
# dtype: object

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# On average, the cloud servers were hit by 13 attempted attacks per minute, per honeypot. The honeypots were set up in 10 of the most popular Amazon Web Services (AWS) data centers in the world, including California, Frankfurt, Ireland, London, Mumbai, Ohio, Paris, Sao Paulo, Singapore, and Sydney over a 30-day period.
#
#        My purpose is to analyze Amazon Web Services (AWS) honeypot data for any trends and/or correlations that could possibly be used in predictive cyber threat vectors. I spent a lot of time looking for data sets and most of the ones I found had no documentation and the data was hard to interpret just from the file. This data is well formatted and straight forward.

# %% [markdown]
# # "MBBS" Team members details

# %% [markdown]
# **1.M Siva Rama Krishna    -  19PA1A05B7 - CSE-B**
#
# **2.K.Bharath Kumar    -  19PA1A0580 - CSE-B**
#
# **3.K.Murali      -  19PA1A0588 - CSE-B**
#
# **4.M.V.S.Bhargav Ram     -  19PA1A05A0 - CSE-B**
